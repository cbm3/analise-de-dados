# %%
#Importando a biblioteca
import pandas as pd

#Leitura da fonte de dados
df = pd.read_excel("/content/dataset-vendas.xlsx")

# %%
df.head()
# Out:
#     Código                                 Nome do produto   Tipo  Quantidade  \
# 0  1000889            Desmistificando Business Inteligence  Ebook           8
# 1  1002334                                      BI na veia  Livro           3
# 2  1002767  Power BI: 10 dicas para o tratamento dos dados  Ebook           5
# 3  1004327                   Tudo sobre o Power BI Desktop  Livro           2
# 4  1013793                                  O poder do DAX  Livro           7
#
#     Preço
# 0   6.309
# 1  42.000
# 2   8.410
# 3  35.000
# 4  24.010

# %%
#Criando a coluna de receita
df["Receita"] = df["Quantidade"].mul(df["Preço"])

# %%
df.head()
# Out:
#     Código                                 Nome do produto   Tipo  Quantidade  \
# 0  1000889            Desmistificando Business Inteligence  Ebook           8
# 1  1002334                                      BI na veia  Livro           3
# 2  1002767  Power BI: 10 dicas para o tratamento dos dados  Ebook           5
# 3  1004327                   Tudo sobre o Power BI Desktop  Livro           2
# 4  1013793                                  O poder do DAX  Livro           7
#
#     Preço  Receita
# 0   6.309   50.472
# 1  42.000  126.000
# 2   8.410   42.050
# 3  35.000   70.000
# 4  24.010  168.070

# %%
#Retornando a maior receira
df["Receita"].max()
# Out:
# 342.108

# %%
#Retornando a menor receita
df["Receita"].min()
# Out:
# 14.736

# %%
#Retornar top 3 maiores receitas (nlargest)
df.nlargest(3, "Receita")
# Out:
#      Código            Nome do produto   Tipo  Quantidade   Preço  Receita
# 5   1022450  A bruxaria da linguagem M  Livro           9  38.012  342.108
# 15   326779        SQL para iniciantes  Livro           8  32.000  256.000
# 13   243083          Performance com M  Livro           5  47.000  235.000

# %%
#Retornar top 3 menores receitas (nsamllest)
df.nsmallest(3, "Receita")
# Out:
#     Código               Nome do produto   Tipo  Quantidade   Preço  Receita
# 21  723457  Utilizando o Power BI Helper  Ebook           3   4.912   14.736
# 16  394479     Direct query com Power BI  Ebook           2   8.409   16.818
# 22  746596                ETL na prática  Livro           1  19.505   19.505

# %%
#Agrupamento por tipo
df.groupby("Tipo")["Receita"].sum()
# Out:
# Tipo
# Ebook     469.7955
# Livro    2275.8030
# Name: Receita, dtype: float64

# %%
#Ordenando o conjunto de dados pela maior receita
df.sort_values("Receita", ascending=False).head(10)
# Out:
#      Código                               Nome do produto   Tipo  Quantidade  \
# 5   1022450                     A bruxaria da linguagem M  Livro           9
# 15   326779                           SQL para iniciantes  Livro           8
# 13   243083                             Performance com M  Livro           5
# 19   520380  Conhecendo as linguagens do Power BI Desktop  Livro           4
# 23   773912                      Power BI para iniciantes  Livro           9
# 4   1013793                                O poder do DAX  Livro           7
# 6   1037797                                  DAX avançado  Livro           6
# 27   838819                                 BI na íntegra  Livro           7
# 1   1002334                                    BI na veia  Livro           3
# 17  4000001        Desenvolvendo dashboards profissionais  Livro           6
#
#      Preço  Receita
# 5   38.012  342.108
# 15  32.000  256.000
# 13  47.000  235.000
# 19  48.990  195.960
# 23  21.000  189.000
# 4   24.010  168.070
# 6   27.000  162.000
# 27  19.870  139.090
# 1   42.000  126.000
# 17  20.000  120.000

# %%
#Ordenando o conjunto de dados
df.sort_values("Nome do produto", ascending=True).head(10)
# Out:
#      Código                               Nome do produto   Tipo  Quantidade  \
# 5   1022450                     A bruxaria da linguagem M  Livro           9
# 20   695594               Analizando dados com o Power BI  Livro           2
# 1   1002334                                    BI na veia  Livro           3
# 27   838819                                 BI na íntegra  Livro           7
# 11  1101035                            BI para iniciantes  Livro           1
# 19   520380  Conhecendo as linguagens do Power BI Desktop  Livro           4
# 6   1037797                                  DAX avançado  Livro           6
# 8   1078680                         Dashboards brilhantes  Ebook           8
# 17  4000001        Desenvolvendo dashboards profissionais  Livro           6
# 0   1000889          Desmistificando Business Inteligence  Ebook           8
#
#       Preço  Receita
# 5   38.0120  342.108
# 20  28.5120   57.024
# 1   42.0000  126.000
# 27  19.8700  139.090
# 11  36.0000   36.000
# 19  48.9900  195.960
# 6   27.0000  162.000
# 8    5.1795   41.436
# 17  20.0000  120.000
# 0    6.3090   50.472

# %%
df["Quantidade"].value_counts(ascending=False).plot.bar()
# Out:
# <Axes: >

# %%
df["Quantidade"].value_counts(ascending=False).plot.barh()
# Out:
# <Axes: >

# %%
#Gráfico de pizza
df.groupby(df["Tipo"])["Receita"].sum().plot.pie()
# Out:
# <Axes: ylabel='Receita'>

# %%
#Adicionando um título e alterando o nome dos eixos
import matplotlib.pyplot as plt

df["Tipo"].value_counts().plot.bar(title="Total vendas por produto")
plt.xlabel("Nome do produto")
plt.ylabel("Receita")
# Out:
# Text(0, 0.5, 'Receita')

# %%
#Alterado a cor
df["Tipo"].value_counts().plot.bar(title="Total vendas por produto", color="red")
plt.xlabel("Nome do produto")
plt.ylabel("Receita")
# Out:
# Text(0, 0.5, 'Receita')

# %%
#Alterado o estilo
plt.style.use("ggplot")

# %%
df.groupby(df["Tipo"])["Quantidade"].sum().plot()
plt.xlabel("Tipo")
plt.ylabel("Quantidade de produtos vendidos")
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>
